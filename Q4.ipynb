# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("Batchwise Attendance Data - Class 1.csv")

# %%
df.head()
# Out:
#    Student Roll Num     Type 10-01-21  R-10-01-21 09-01-21  R-9-01-21  \
# 0                 1  WORKING   Missed           7   Missed          5
# 1                 2      NaN   Missed           7   Missed          9
# 2                 3  STUDENT   Missed          10   Missed          8
# 3                 4  STUDENT   Missed           8   Missed          5
# 4                 5  WORKING   Missed           6   Missed          8
#
#    08-01-21  R-8-01-21  07-01-21  R-7-01-21  ...  05-01-21  R-5-01-21  \
# 0    Missed          6    Missed         10  ...    Missed         10
# 1    Missed          5  Attended          9  ...  Attended          9
# 2    Missed         10    Missed         10  ...  Attended          5
# 3  Attended          8    Missed          6  ...    Missed          6
# 4    Missed          7    Missed          8  ...    Missed          9
#
#    04-01-21  R-4-01-21  03-01-21  R-3-01-21  02-01-21  R-02-01-21  01-01-21  \
# ...

# %%
df2=df.fillna("STUDENT")

# %%
df2
# Out:
#     Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21  \
# 0                  1  WORKING    Missed           7    Missed          5
# 1                  2  STUDENT    Missed           7    Missed          9
# 2                  3  STUDENT    Missed          10    Missed          8
# 3                  4  STUDENT    Missed           8    Missed          5
# 4                  5  WORKING    Missed           6    Missed          8
# 5                  6  STUDENT    Missed           8    Missed         10
# 6                  7  STUDENT  Attended           9  Attended          9
# 7                  8  STUDENT    Missed           5    Missed         10
# 8                  9   IGNORE    Missed           9    Missed          7
# 9                 10  STUDENT    Missed           7    Missed          6
# 10                11  STUDENT  Attended           7  Attended          8
# 11                12  STUDENT  Attended           8  Attended          5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Student Roll Num  57 non-null     int64
#  1   Type              32 non-null     object
#  2   10-01-21          57 non-null     object
#  3   R-10-01-21        57 non-null     int64
#  4   09-01-21          57 non-null     object
#  5   R-9-01-21         57 non-null     int64
#  6   08-01-21          57 non-null     object
#  7   R-8-01-21         57 non-null     int64
#  8   07-01-21          56 non-null     object
#  9   R-7-01-21         57 non-null     int64
#  10  06-01-21          56 non-null     object
#  11  R-6-01-21         57 non-null     int64
#  12  05-01-21          56 non-null     object
#  13  R-5-01-21         57 non-null     int64
#  14  04-01-21          56 non-null     object
#  15  R-4-01-21         57 non-null     int64
# ...

# %%
df2.head()
# Out:
#    Student Roll Num     Type 10-01-21  R-10-01-21 09-01-21  R-9-01-21  \
# 0                 1  WORKING   Missed           7   Missed          5
# 1                 2  STUDENT   Missed           7   Missed          9
# 2                 3  STUDENT   Missed          10   Missed          8
# 3                 4  STUDENT   Missed           8   Missed          5
# 4                 5  WORKING   Missed           6   Missed          8
#
#    08-01-21  R-8-01-21  07-01-21  R-7-01-21  ...  05-01-21  R-5-01-21  \
# 0    Missed          6    Missed         10  ...    Missed         10
# 1    Missed          5  Attended          9  ...  Attended          9
# 2    Missed         10    Missed         10  ...  Attended          5
# 3  Attended          8    Missed          6  ...    Missed          6
# 4    Missed          7    Missed          8  ...    Missed          9
#
#    04-01-21  R-4-01-21  03-01-21  R-3-01-21  02-01-21  R-02-01-21  01-01-21  \
# ...

# %%
sns.displot(df2["Type"])

# %%
sns.jointplot(df2['R-10-01-21'],df2['10-01-21'])
# Out:
# C:\Users\MAYURI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
g=df.groupby("Type")

# %%
g

# %%
for Type,Type_df in g:
    print(Type)
    print(Type_df)
# Out:
# DROPOUT
#     Student Roll Num     Type 10-01-21  R-10-01-21 09-01-21  R-9-01-21  \
# 51                52  DROPOUT   Missed           7   Missed         10
#
#    08-01-21  R-8-01-21 07-01-21  R-7-01-21  ... 05-01-21  R-5-01-21 04-01-21  \
# 51   Missed          8   Missed          6  ...   Missed          9   Missed
#
#     R-4-01-21 03-01-21  R-3-01-21 02-01-21  R-02-01-21 01-01-21  R-01-01-21
# 51          5   Missed          7   Missed           6   Missed           7
#
# [1 rows x 22 columns]
# IGNORE
#     Student Roll Num    Type 10-01-21  R-10-01-21 09-01-21  R-9-01-21  \
# 8                  9  IGNORE   Missed           9   Missed          7
# 49                50  IGNORE   Missed           9   Missed          6
#
#    08-01-21  R-8-01-21 07-01-21  R-7-01-21  ... 05-01-21  R-5-01-21 04-01-21  \
# 8    Missed         10   Missed          9  ...   Missed         10   Missed
# 49   Missed          8   Missed          5  ...   Missed         10   Missed
#
# ...

# %%
g.get_group('STUDENT')
# Out:
#     Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21  \
# 2                  3  STUDENT    Missed          10    Missed          8
# 3                  4  STUDENT    Missed           8    Missed          5
# 6                  7  STUDENT  Attended           9  Attended          9
# 7                  8  STUDENT    Missed           5    Missed         10
# 10                11  STUDENT  Attended           7  Attended          8
# 11                12  STUDENT  Attended           8  Attended          5
# 12                13  STUDENT  Attended           6  Attended          5
# 13                14  STUDENT  Attended           6  Attended          9
# 16                17  STUDENT  Attended           5  Attended          6
# 24                25  STUDENT  Attended          10  Attended          7
# 25                26  STUDENT  Attended           5  Attended         10
# 27                28  STUDENT  Attended           5  Attended          6
# ...

# %%
g.max()
# Out:
#          Student Roll Num 10-01-21  R-10-01-21 09-01-21  R-9-01-21 08-01-21  \
# Type
# DROPOUT                52   Missed           7   Missed         10   Missed
# IGNORE                 50   Missed           9   Missed          7   Missed
# STUDENT                51   Missed          10   Missed         10   Missed
# WORKING                55   Missed           8   Missed         10   Missed
#
#          R-8-01-21 07-01-21  R-7-01-21 06-01-21  ...  05-01-21 R-5-01-21  \
# Type                                             ...
# DROPOUT          8   Missed          6   Missed  ...    Missed         9
# IGNORE          10   Missed          9   Missed  ...    Missed        10
# STUDENT         10   Missed         10   Missed  ...    Missed        10
# WORKING         10   Missed         10   Missed  ...    Missed        10
#
#          04-01-21 R-4-01-21  03-01-21 R-3-01-21  02-01-21 R-02-01-21  \
# Type
# DROPOUT    Missed         5    Missed         7    Missed          6
# ...

# %%
g['STUDENT',axis=1].max()
# Out:
#   File "<ipython-input-29-92ebad26b1ac>", line 1
#     g['STUDENT',axis=1].max()
#                     ^
# SyntaxError: invalid syntax

# %%
g.min()
# Out:
#          Student Roll Num  10-01-21  R-10-01-21  09-01-21  R-9-01-21  \
# Type
# DROPOUT                52    Missed           7    Missed         10
# IGNORE                  9    Missed           9    Missed          6
# STUDENT                 3  Attended           5  Attended          5
# WORKING                 1  Attended           5  Attended          5
#
#          08-01-21  R-8-01-21  07-01-21  R-7-01-21  06-01-21  ...  05-01-21  \
# Type                                                         ...
# DROPOUT    Missed          8    Missed          6    Missed  ...    Missed
# IGNORE     Missed          8    Missed          5    Missed  ...    Missed
# STUDENT  Attended          5  Attended          5  Attended  ...  Attended
# WORKING  Attended          5  Attended          5  Attended  ...  Attended
#
#         R-5-01-21  04-01-21 R-4-01-21  03-01-21 R-3-01-21  02-01-21  \
# Type
# DROPOUT         9    Missed         5    Missed         7    Missed
# ...

# %%
# %matplotlib inline
g.plot()
# Out:
# Type
# DROPOUT    AxesSubplot(0.125,0.125;0.775x0.755)
# IGNORE     AxesSubplot(0.125,0.125;0.775x0.755)
# STUDENT    AxesSubplot(0.125,0.125;0.775x0.755)
# WORKING    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
g.mean().plot()
# Out:
# <AxesSubplot:xlabel='Type'>

# %%
g.max().plot()
# Out:
# <AxesSubplot:xlabel='Type'>

# %%
g.min().plot()
# Out:
# <AxesSubplot:xlabel='Type'>

# %%
# !pip install plotly

# %%
import pandas as pd
import numpy as np
import plotly.figure_factory as ff
import plotly.offline as py
import plotly.graph_objs as go
import plotly.express as px
import datetime as dt

import plotly.io as pio
pio.templates.default = "ggplot2

# %%
trace0 = go.Scatter(x=nflx.Date, y=nflx.Close, name='nflx')
fig0 = go.Figure([trace0])
fig0.update_layout(
    title={
        'text': "Netflix Stock Price",
        'x':0.5,
        'xanchor': 'center'})
fig0.show()
